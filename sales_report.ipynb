# %%
import pandas as pd

# %%
sales=pd.read_csv('sales.csv')

# %%
sales
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
sales.head(10)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8   325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9   562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 1    Fashion     35         5    175    Card       3
# ...

# %%
sales['Invoice ID']
# Out:
# 0      460489604
# 1      471006167
# 2      411909258
# 3      487313402
# 4      197763430
#          ...
# 995    818829599
# 996    556589713
# 997     82324424
# 998    783661702
# 999    759171975
# Name: Invoice ID, Length: 1000, dtype: int64

# %%
sales['Category'].unique()
# Out:
# array(['Groceries', 'Fashion', 'Clothing', 'Sporting', 'Books',
#        'Furniture'], dtype=object)

# %%
sales.iloc[200]
# Out:
# Invoice ID      576523018
# Date            2/15/2018
# Time                12:35
# Gender               Male
# Location      Water tower
# City              Chicago
# Member                 No
# Category        Groceries
# Price                  82
# Quantity                1
# Total                  82
# Payment              Card
# Rating                  4
# Name: 200, dtype: object

# %%
sales[200:210]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 200   576523018  2/15/2018  12:35    Male  Water tower  Chicago     No
# 201   414119922  1/30/2018  11:07    Male  Water tower  Chicago     No
# 202   123247697   2/8/2018  20:03    Male   Brookfield  NewYork     No
# 203    40419058  1/26/2018  14:53    Male  Water tower  Chicago    Yes
# 204   890497298  2/25/2018  18:06  Female  Water tower  Chicago     No
# 205   885702268  1/28/2018  12:45    Male   Brookfield  NewYork     No
# 206   172252194  3/22/2018  20:10  Female    Park lane   Dallas     No
# 207   866140211  2/25/2018  13:34  Female    Park lane   Dallas     No
# 208   597678548  3/15/2018  17:35    Male  Water tower  Chicago    Yes
# 209   428818456  2/25/2018  18:50    Male    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 200  Groceries     82         1     82    Card       4
# 201   Sporting     44         7    308    Card       3
# ...

# %%
sales.tail()
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 995  Groceries     31         4    124    Card       3
# 996  Groceries      3         5     15    Gpay       3
# 997   Clothing     71         5    355    Card       3
# 998   Clothing     89         7    623    Cash       5
# 999   Clothing     31         7    217    Gpay       3

# %%
sales[sales['Gender']=='Female']
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 9     562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
# 10    388412668  2/26/2018  11:32  Female   Brookfield  NewYork     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 988      737210  1/20/2018  20:47  Female  Water tower  Chicago    Yes
# 989   941364541  3/13/2018  14:53  Female   Brookfield  NewYork     No
# 993   455112063  3/19/2018  17:30  Female   Brookfield  NewYork    Yes
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 1      Fashion     35         5    175    Card       3
# ...

# %%
sales[sales['Gender']=='Male'].head(10)
# Out:
#     Invoice ID       Date   Time Gender     Location     City Member  \
# 0    460489604  1/25/2018  16:46   Male   Brookfield  NewYork    Yes
# 2    411909258  2/25/2018  13:33   Male  Water tower  Chicago     No
# 5    263634050   3/9/2018  17:55   Male   Brookfield  NewYork    Yes
# 6     99646662   3/4/2018  13:21   Male  Water tower  Chicago     No
# 7    188869875   3/8/2018  13:24   Male    Park lane   Dallas     No
# 8    325637547  1/18/2018  15:33   Male    Park lane   Dallas    Yes
# 11   846531724  3/15/2018  12:12   Male    Park lane   Dallas     No
# 12   149894432  1/12/2018  11:12   Male    Park lane   Dallas     No
# 17    90524319  3/19/2018  18:18   Male    Park lane   Dallas    Yes
# 19   729486362   3/7/2018  12:50   Male  Water tower  Chicago     No
#
#      Category  Price  Quantity  Total Payment  Rating
# 0   Groceries     30         1     30    Cash       2
# 2    Clothing     57         2    114    Cash       5
# ...

# %%
#print total>100
sales[sales['Total']>100]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5     263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# ..          ...        ...    ...     ...          ...      ...    ...
# 994   446582560  1/31/2018  19:00    Male  Water tower  Chicago     No
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 1      Fashion     35         5    175    Card       3
# ...

# %%
sales['Payment'].unique()
# Out:
# array(['Cash', 'Card', 'Gpay'], dtype=object)

# %%
sales[sales['Payment']=='Cash']
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 6      99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 989   941364541  3/13/2018  14:53  Female   Brookfield  NewYork     No
# 990   752407865  1/15/2018  10:01    Male  Water tower  Chicago    Yes
# 993   455112063  3/19/2018  17:30  Female   Brookfield  NewYork    Yes
# 994   446582560  1/31/2018  19:00    Male  Water tower  Chicago     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
#print  only Newyork city based 
sales[sales['City']=='NewYork']
# Out:
#      Invoice ID       Date   Time  Gender    Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male  Brookfield  NewYork    Yes
# 5     263634050   3/9/2018  17:55    Male  Brookfield  NewYork    Yes
# 10    388412668  2/26/2018  11:32  Female  Brookfield  NewYork     No
# 14    547572603  3/21/2018  13:23  Female  Brookfield  NewYork     No
# 15    355981315  2/15/2018  15:47  Female  Brookfield  NewYork    Yes
# ..          ...        ...    ...     ...         ...      ...    ...
# 991   699906043  2/15/2018  12:58    Male  Brookfield  NewYork    Yes
# 992   927909627   3/2/2018  13:35    Male  Brookfield  NewYork     No
# 993   455112063  3/19/2018  17:30  Female  Brookfield  NewYork    Yes
# 997    82324424   2/6/2018  11:44    Male  Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female  Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
# print category
sales['Category'].unique()
# Out:
# array(['Groceries', 'Fashion', 'Clothing', 'Sporting', 'Books',
#        'Furniture'], dtype=object)

# %%
sales[sales['Total'].between(100,200) ]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 9     562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
# 10    388412668  2/26/2018  11:32  Female   Brookfield  NewYork     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 981   418253101  3/14/2018  12:25  Female   Brookfield  NewYork     No
# 989   941364541  3/13/2018  14:53  Female   Brookfield  NewYork     No
# 990   752407865  1/15/2018  10:01    Male  Water tower  Chicago    Yes
# 994   446582560  1/31/2018  19:00    Male  Water tower  Chicago     No
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 1      Fashion     35         5    175    Card       3
# ...

# %%
#sum in particular fields
sales.sum()['Total']
# Out:
# 207788

# %%
sales.sum()['Quantity']
# Out:
# 4059

# %%
sales.max()
# Out:
# Invoice ID      999665753
# Date             3/9/2018
# Time                20:59
# Gender               Male
# Location      Water tower
# City              NewYork
# Member                Yes
# Category         Sporting
# Price                 100
# Quantity                7
# Total                 693
# Payment              Gpay
# Rating                  5
# dtype: object

# %%
sales.max()['Total']
# Out:
# 693

# %%
sales[sales['Total']==sales.max()['Total']]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 47    315624039  3/30/2018  19:45  Female  Water tower  Chicago    Yes
# 679   270918350  3/27/2018  13:21  Female    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 47   Groceries     99         7    693    Gpay       3
# 679  Groceries     99         7    693    Gpay       2

# %%
sales['Total'].min()
# Out:
# 1

# %%
sales['Invoice ID'].max()
# Out:
# 999665753

# %%
sales[sales['Invoice ID']==sales.max()['Invoice ID']]
# Out:
#      Invoice ID      Date   Time Gender    Location     City Member  \
# 905   999665753  3/5/2018  18:45   Male  Brookfield  NewYork    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 905  Groceries     38         6    228    Gpay       5

# %%
sales['Invoice ID'].min()
# Out:
# 661405

# %%
sales['Invoice ID'].mean()
# Out:
# 494493053.341

# %%
sales.head(10)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8   325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9   562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 1    Fashion     35         5    175    Card       3
# ...

# %%
#sum in particular fields
sales.groupby('City').sum()
# Out:
# C:\Users\vyshn\AppData\Local\Temp\ipykernel_7500\2501838167.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby('City').sum()
#            Invoice ID  Price  Quantity  Total  Rating
# City
# Chicago  164244758326  16152      1307  65215    1023
# Dallas   160721744770  17289      1344  70432    1003
# NewYork  169526550245  17671      1408  72141     946

# %%
sales.groupby('City').sum()['Total']
# Out:
# C:\Users\vyshn\AppData\Local\Temp\ipykernel_7500\2787673646.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby('City').sum()['Total']
# City
# Chicago    65215
# Dallas     70432
# NewYork    72141
# Name: Total, dtype: int64

# %%
sales.groupby('Date').sum()['Total']
# Out:
# C:\Users\vyshn\AppData\Local\Temp\ipykernel_7500\1807407803.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby('Date').sum()['Total']
# Date
# 1/1/2018     2649
# 1/10/2018    1116
# 1/11/2018    1562
# 1/12/2018    2625
# 1/13/2018    2340
#              ...
# 3/5/2018     4616
# 3/6/2018     1915
# 3/7/2018     1048
# 3/8/2018     2638
# 3/9/2018     4300
# Name: Total, Length: 89, dtype: int64

# %%
sales.groupby('Gender').sum()['Total']
# Out:
# C:\Users\vyshn\AppData\Local\Temp\ipykernel_7500\2702593002.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby('Gender').sum()['Total']
# Gender
# Female    106452
# Male      101336
# Name: Total, dtype: int64

# %%
sales.groupby('City').sum()['Total']
# Out:
# C:\Users\vyshn\AppData\Local\Temp\ipykernel_7500\2787673646.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby('City').sum()['Total']
# City
# Chicago    65215
# Dallas     70432
# NewYork    72141
# Name: Total, dtype: int64

# %%
sales.groupby('Category').sum()['Rating']
# Out:
# C:\Users\vyshn\AppData\Local\Temp\ipykernel_7500\3272393049.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby('Category').sum()['Rating']
# Category
# Books        481
# Clothing     509
# Fashion      458
# Furniture    506
# Groceries    512
# Sporting     506
# Name: Rating, dtype: int64

# %%
sales.groupby('Member').sum()['Total']
# Out:
# C:\Users\vyshn\AppData\Local\Temp\ipykernel_7500\2427425673.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby('Member').sum()['Total']
# Member
# No     100245
# Yes    107543
# Name: Total, dtype: int64

# %%
#which location has heighest and loweset sales ?
#represent the sales on a bar char , also show the market share for each location using a pie chart

# %%
sales
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
location_list=sales.groupby('Location')

# %%
location=[x for x,y in location_list]

# %%
location
# Out:
# ['Brookfield', 'Park lane', 'Water tower']

# %%
t=sales.groupby('Location').sum()['Total']
# Out:
# C:\Users\vyshn\AppData\Local\Temp\ipykernel_7500\2431675980.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   t=sales.groupby('Location').sum()['Total']

# %%
t
# Out:
# Location
# Brookfield     72141
# Park lane      70432
# Water tower    65215
# Name: Total, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.show(location,t)

# %%
plt.bar(location,t)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.pie(t,labels=location,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x21147773dd0>,
# ...
#  [Text(0.5080357843151302, 0.9756534435214743, 'Brookfield'),
#   Text(-1.0939745592878725, -0.11497679605427102, 'Park lane'),
#   Text(0.6072323961649048, -0.917207074246502, 'Water tower')],
#  [Text(0.2771104278082528, 0.5321746055571678, '34.7%'),
#   Text(-0.596713395975203, -0.06271461602960236, '33.9%'),
#   Text(0.33121767063540253, -0.5002947677708193, '31.4%')])

# %%
#which location has more female customer and which location has more male

# %%
location_sales=sales.groupby(['Gender','Location']).count()['Invoice ID']

# %%
location_sales
# Out:
# Location     Gender
# Brookfield   Female    179
#              Male      161
# Park lane    Female    179
#              Male      153
# Water tower  Female    143
#              Male      185
# Name: Invoice ID, dtype: int64

# %%
unstack_sales=location_sales.unstack(level=0)

# %%
unstack_sales
# Out:
# Gender       Female  Male
# Location
# Brookfield      179   161
# Park lane       179   153
# Water tower     143   185

# %%
unstack_sales.plot(kind='bar')
# Out:
# <Axes: xlabel='Location'>

# %%
#what days of the month make most sales?

# %%
sales['Date']
# Out:
# 0      1/25/2018
# 1      3/19/2018
# 2      2/25/2018
# 3      1/22/2018
# 4      2/18/2018
#          ...
# 995    3/26/2018
# 996    2/20/2018
# 997     2/6/2018
# 998    1/29/2018
# 999    1/31/2018
# Name: Date, Length: 1000, dtype: object

# %%
#convert date
pd.to_datetime(sales['Date'])
# Out:
# 0     2018-01-25
# 1     2018-03-19
# 2     2018-02-25
# 3     2018-01-22
# 4     2018-02-18
#          ...
# 995   2018-03-26
# 996   2018-02-20
# 997   2018-02-06
# 998   2018-01-29
# 999   2018-01-31
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
#print day in date
pd.to_datetime(sales['Date']).dt.day #month,year
# Out:
# 0      25
# 1      19
# 2      25
# 3      22
# 4      18
#        ..
# 995    26
# 996    20
# 997     6
# 998    29
# 999    31
# Name: Date, Length: 1000, dtype: int64

# %%
sales['Day']=pd.to_datetime(sales['Date']).dt.day

# %%
sales.head(5)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  Day
# 0  Groceries     30         1     30    Cash       2   25
# 1    Fashion     35         5    175    Card       3   19
# 2   Clothing     57         2    114    Cash       5   25
# 3   Sporting     89         4    356    Gpay       1   22
# 4      Books     82         5    410    Cash       4   18

# %%
day_sales=sales.groupby('Day').sum()['Total']
# Out:
# C:\Users\vyshn\AppData\Local\Temp\ipykernel_7500\2833411917.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   day_sales=sales.groupby('Day').sum()['Total']

# %%
day_sales
# Out:
# Day
# 1     6301
# 2     8247
# 3     8533
# 4     6593
# 5     9177
# 6     5976
# 7     6164
# 8     8313
# 9     9142
# 10    6444
# 11    4755
# 12    7714
# 13    5688
# 14    7978
# 15    9677
# 16    5912
# 17    5833
# 18    4625
# 19    7481
# 20    7333
# 21    4300
# 22    5788
# 23    6949
# 24    7819
# 25    8638
# 26    7165
# 27    8154
# 28    6467
# 29    4662
# 30    3530
# 31    2430
# Name: Total, dtype: int64

# %%
day_sales.plot()
# Out:
# <Axes: xlabel='Day'>

# %%
#

# %%
sales
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating  Day
# ...

# %%
sales['Member']
# Out:
# 0      Yes
# 1      Yes
# 2       No
# 3      Yes
# 4       No
#       ...
# 995     No
# 996    Yes
# 997     No
# 998     No
# 999    Yes
# Name: Member, Length: 1000, dtype: object

# %%
sales['Member'].count()
# Out:
# 1000

# %%
sales.groupby('Member').sum()
# Out:
# C:\Users\vyshn\AppData\Local\Temp\ipykernel_7500\2472307024.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby('Member').sum()
#           Invoice ID  Price  Quantity   Total  Rating   Day
# Member
# No      242503049716  25129      2013  100245    1504  7617
# Yes     251990003625  25983      2046  107543    1468  7639

# %%
mem=sales.groupby(['Gender','Member']).count()['City']

# %%
mem
# Out:
# Gender  Member
# Female  No        253
#         Yes       248
# Male    No        246
#         Yes       253
# Name: City, dtype: int64

# %%
unstack_gender=mem.unstack(level=0)

# %%
unstack_gender
# Out:
# Gender  Female  Male
# Member
# No         253   246
# Yes        248   253

# %%
unstack_gender.plot(kind='bar')
# Out:
# <Axes: xlabel='Member'>

# %%
sales[sales['Member']== 'Yes' ]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 5     263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 8     325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# ..          ...        ...    ...     ...          ...      ...    ...
# 990   752407865  1/15/2018  10:01    Male  Water tower  Chicago    Yes
# 991   699906043  2/15/2018  12:58    Male   Brookfield  NewYork    Yes
# 993   455112063  3/19/2018  17:30  Female   Brookfield  NewYork    Yes
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating  Day
# ...

# %%
sales[sales['Member']== 'Yes' ].count()
# Out:
# Invoice ID    501
# Date          501
# Time          501
# Gender        501
# Location      501
# City          501
# Member        501
# Category      501
# Price         501
# Quantity      501
# Total         501
# Payment       501
# Rating        501
# Day           501
# dtype: int64

# %%
#which branch has more members and less members ?
#which branch has highest rating and which has the lowest rating ?

# %%
sales.head(2)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
#
#     Category  Price  Quantity  Total Payment  Rating  Day
# 0  Groceries     30         1     30    Cash       2   25
# 1    Fashion     35         5    175    Card       3   19

# %%
members=sales.groupby(['Member','Location']).count()['Invoice ID']

# %%
members
# Out:
# Member  Location
# No      Brookfield     173
#         Park lane      167
#         Water tower    159
# Yes     Brookfield     167
#         Park lane      165
#         Water tower    169
# Name: Invoice ID, dtype: int64

# %%
members.unstack(level=0)
# Out:
# Member        No  Yes
# Location
# Brookfield   173  167
# Park lane    167  165
# Water tower  159  169

# %%
members.unstack(level=0).plot(kind='bar')
# Out:
# <Axes: xlabel='Location'>

# %%
sales.groupby(['Location']).mean()['Rating']
# Out:
# C:\Users\vyshn\AppData\Local\Temp\ipykernel_7500\2869637473.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby(['Location']).mean()['Rating']
# Location
# Brookfield     2.782353
# Park lane      3.021084
# Water tower    3.118902
# Name: Rating, dtype: float64

# %%
sales.groupby(['Location']).mean()['Rating'].plot(kind='bar')
# Out:
# C:\Users\vyshn\AppData\Local\Temp\ipykernel_7500\982081795.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby(['Location']).mean()['Rating'].plot(kind='bar')
# <Axes: xlabel='Location'>

# %%
#which city has more female shopping

# %%
sales['City'].unique()
# Out:
# array(['NewYork', 'Chicago', 'Dallas'], dtype=object)

# %%
sales[sales['Gender']=='Female']
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 9     562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
# 10    388412668  2/26/2018  11:32  Female   Brookfield  NewYork     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 988      737210  1/20/2018  20:47  Female  Water tower  Chicago    Yes
# 989   941364541  3/13/2018  14:53  Female   Brookfield  NewYork     No
# 993   455112063  3/19/2018  17:30  Female   Brookfield  NewYork    Yes
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating  Day
# ...

# %%
shoping=sales.groupby(['Gender','City']).count()['Invoice ID']

# %%
shoping
# Out:
# Gender  City
# Female  Chicago    143
#         Dallas     179
#         NewYork    179
# Male    Chicago    185
#         Dallas     153
#         NewYork    161
# Name: Invoice ID, dtype: int64

# %%
shoping.unstack(level=0).plot(kind='bar')
# Out:
# <Axes: xlabel='City'>

# %%
#who spends more men or female ?

# %%
sales.groupby('Gender').sum()
# Out:
# C:\Users\vyshn\AppData\Local\Temp\ipykernel_7500\900275231.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales.groupby('Gender').sum()
#           Invoice ID  Price  Quantity   Total  Rating   Day
# Gender
# Female  253138028847  25474      2069  106452    1517  7700
# Male    241355024494  25638      1990  101336    1455  7556

# %%
spend=sales.groupby('Gender').sum()['Total']
# Out:
# C:\Users\vyshn\AppData\Local\Temp\ipykernel_7500\4030090913.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   spend=sales.groupby('Gender').sum()['Total']

# %%
spend.plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
#which type of customer spends more member or non member

# %%
type=sales.groupby(['Member']).sum()['Total']
# Out:
# C:\Users\vyshn\AppData\Local\Temp\ipykernel_7500\3129463932.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   type=sales.groupby(['Member']).sum()['Total']

# %%
type
# Out:
# Member
# No     100245
# Yes    107543
# Name: Total, dtype: int64

# %%
type.plot(kind='bar')
# Out:
# <Axes: xlabel='Member'>

# %%
#which product line sells more ?

# %%
sell=sales.groupby('Category').count()['Total']

# %%
sell.plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
#which product line is popular among men vs women ?

# %%
line=sales.groupby(['Gender','Category']).count()['Total']

# %%
line.unstack(level=0).plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
#which month has more sales ?

# %%
sales['Month']=pd.to_datetime(sales['Date']).dt.month

# %%
sales['Month']
# Out:
# 0      1
# 1      3
# 2      2
# 3      1
# 4      2
#       ..
# 995    3
# 996    2
# 997    2
# 998    1
# 999    1
# Name: Month, Length: 1000, dtype: int64

# %%
sales.head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  Day  month  Month
# 0  Groceries     30         1     30    Cash       2   25      1      1
# 1    Fashion     35         5    175    Card       3   19      3      3
# 2   Clothing     57         2    114    Cash       5   25      2      2
# 3   Sporting     89         4    356    Gpay       1   22      1      1
# 4      Books     82         5    410    Cash       4   18      2      2

# %%
sales_by_month=sales.groupby('Month').sum()['Total']
# Out:
# C:\Users\vyshn\AppData\Local\Temp\ipykernel_7500\3729761029.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales_by_month=sales.groupby('Month').sum()['Total']

# %%
sales_by_month
# Out:
# Month
# 1    71652
# 2    63850
# 3    72286
# Name: Total, dtype: int64

# %%
sales_by_month.plot(kind='bar')
# Out:
# <Axes: xlabel='Month'>
